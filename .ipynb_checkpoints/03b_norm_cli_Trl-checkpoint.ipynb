# %%
# load libraies

# %run py_libraries.py
# Out:
# /Users/4476224/.local/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.13.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# ...

# %%
# Ex data

# load data
Ex_data = pd.read_csv('data/Ex_baselinedata.csv')
# data = data.loc[0:317]

print(Ex_data.shape)
# Out:
# (14, 16)

# %%
# Ex data

Ex_data = Ex_data.apply(pd.to_numeric) # convert all columns of Ndata to numerics

# %%
# Ex data

# No_TIL v Yes_TIL
Ex_ndata_Yes_No = Ex_data
Ex_ndata_Yes_No.reset_index(drop=True, inplace=True)
print(Ex_ndata_Yes_No.shape)
# Out:
# (14, 16)

# %%
# Ex data

Ex_X = Ex_ndata_Yes_No.iloc[:,:-1]
Ex_y = Ex_ndata_Yes_No.iloc[:, -1] #.values

# X.head()

# %%
def data_split(X,y,rnd_st,tst_sz):
    X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                        test_size = tst_sz, 
                                                        random_state=rnd_st,
                                                        stratify=y)
    
    return X_train, X_test, y_train, y_test

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, MaxAbsScaler

# scaler0 = StandardScaler().fit(X_train) # build a scaler for the training data
# scaler0 = MinMaxScaler().fit(X_train) # build a scaler for the training data
# scaler0 = MaxAbsScaler().fit(X_train) # build a scaler for the training data
# scaler0 = RobustScaler().fit(X_train) # build a scaler for the training data

# %%
# Ex data

# save to csv file

# 
Ex_X.to_csv('data/Ex_X_Yes_No.csv', index=False)

# %%
# Ex data

# save to csv file

# 
Ex_y.to_csv('data/Ex_y_Yes_No.csv', index=False)
